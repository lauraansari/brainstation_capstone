# %% [markdown]
# ### **Notebook 4 - Pre-processing and modeling: Linear Regression**

# %% [markdown]
# ### Introduction
#
# In this section, ...

# %% [markdown]
# Table of content:
#
# Data preprocessing:
#
# -
# Modeling:
#
# - Baseline model
# -

# %% [markdown]
# ***
#
# ### Loading data and importing libraries

# %%
# Importing libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go
from statsmodels.api import tsa
import statsmodels.api as sm

# %%
# Loading dataset

aqi_df = pd.read_csv('data/cleaned_aqi.csv', parse_dates=['Date'], index_col='Date')
aqi_df.sample(5)
# Out:
#             AQI                        Category Defining Parameter  \
# Date
# 1986-11-04  110  Unhealthy for Sensitive Groups                NO2
# 2012-02-13   48                            Good              PM2.5
# 1999-12-28   82                        Moderate                 CO
# 2002-02-15  123  Unhealthy for Sensitive Groups              PM2.5
# 1996-01-15  110  Unhealthy for Sensitive Groups                NO2
#
#             Number of Sites Reporting   city_ascii  state_name      lat  \
# Date
# 1986-11-04                         20  Los Angeles  California  34.1141
# 2012-02-13                         20  Los Angeles  California  34.1141
# 1999-12-28                         19  Los Angeles  California  34.1141
# 2002-02-15                         20  Los Angeles  California  34.1141
# 1996-01-15                         19  Los Angeles  California  34.1141
#
#                  lng  population  density             timezone  Year  Month  \
# Date
# 1986-11-04 -118.4068  12531334.0   3267.0  America/Los_Angeles  1986     11
# 2012-02-13 -118.4068  12531334.0   3267.0  America/Los_Angeles  2012      2
# 1999-12-28 -118.4068  12531334.0   3267.0  America/Los_Angeles  1999     12
# 2002-02-15 -118.4068  12531334.0   3267.0  America/Los_Angeles  2002      2
# 1996-01-15 -118.4068  12531334.0   3267.0  America/Los_Angeles  1996      1
#
#             Day
# Date
# 1986-11-04    4
# 2012-02-13   13
# 1999-12-28   28
# 2002-02-15   15
# 1996-01-15   15
